# %%
from Descriptive import *
# Out:
# 41.583
# 197.0
# Ozone      0
# Solar      0
# Wind       0
# Temp       0
# Month      0
# Day        0
# Year       0
# Temp       0
# Weather    0
# dtype: int64
# Weather
# S     63
# C     49
# PS    46
# Name: count, dtype: int64
# 135.0
# 168.0

# %%
data.head()
# Out:
#     Ozone  Solar  Wind  Temp Month  Day  Year  Temp Weather
# 0  41.000  190.0   7.4    67     5    1  2010    67       S
# 1  36.000  118.0   8.0    72     5    2  2010    72       C
# 2  12.000  149.0  12.6    74     5    3  2010    74       S
# 3  18.000  313.0  11.5    62     5    4  2010    62       S
# 4  41.583  197.0  14.3    56     5    5  2010    56       S

# %%
sns.violinplot(data= data['Ozone'],color = 'lightgreen')
plt.title('Violin Plot')
plt.xlabel('Level of O3')
plt.ylabel('Degree')
plt.show()

# %%
sns.violinplot(data = data,x = 'Weather',y='Solar',palette = 'Set2')
# Out:
# <Axes: xlabel='Weather', ylabel='Solar'>

# %%
sns.swarmplot(data = data,x= 'Weather',y = 'Ozone',color = 'Orange',palette = 'Set2',size = 6)
plt.show()

# %%
fig , axes = plt.subplots(2,2,figsize =(10,10))
sns.swarmplot(data = data,x = 'Weather',y = 'Solar',color = 'blue',palette = 'Set2',ax = axes[0][0])
axes[0][0].set_title('SwarmPlot Solar')
sns.swarmplot(data = data,x = 'Weather',y = 'Wind',color = 'blue',palette = 'Set2',ax = axes[0][1])
axes[0][1].set_title('SwarmPlot Solar')
sns.swarmplot(data = data,x = 'Weather',y = 'Wind',color = 'blue',palette = 'Set2',ax = axes[1][1])
axes[1][1].set_title('SwarmPlot Solar')
sns.swarmplot(data = data,x = 'Weather',y = 'Ozone',color = 'blue',palette = 'Set2',ax = axes[1][0])
axes[1][0].set_title('SwarmPlot Solar')
plt.show()

# %%
sns.kdeplot(data = data['Ozone'],fill=True,color = 'lightgreen')
sns.rugplot(data = data['Ozone'],color = 'black')
# Out:
# <Axes: xlabel='Ozone', ylabel='Density'>

# %%
data['Sum'] = data['Solar']+ data['Ozone']

# %%
fig , axes = plt.subplots(2,2,figsize =(10,10))
sns.kdeplot(data = data['Ozone'],fill=True,color = 'lightgreen',ax = axes[0][0])
sns.rugplot(data = data['Ozone'],color = 'black',ax = axes[0][0])
sns.kdeplot(data = data['Solar'],fill=True,color = 'lightblue',ax = axes[0][1])
sns.rugplot(data = data['Solar'],color = 'black',ax = axes[0][1])
sns.kdeplot(data = data['Wind'],fill=True,color = 'blue',ax = axes[1][0])
sns.rugplot(data = data['Wind'],color = 'black',ax = axes[1][0])
sns.kdeplot(data = data['Sum'],fill=True,color = 'yellow',ax = axes[1][1])
sns.rugplot(data = data['Sum'],color = 'black',ax = axes[1][1])
plt.show()

# %%
sns.boxplot(data = data, x = 'Weather',y = 'Ozone')
plt.show()

# %%
plt.scatter(data['Wind'],data['Solar'])
plt.show()

# %%
import numpy as np

# %%
arr = np.random.normal(12,1.5,1000)
arr2 = np.random.normal(15,1.5,1000)

plt.scatter(arr,arr2,alpha = 0.5,marker = '*',color = 'blue')
plt.show()
